# %%
animales = ["panda", "tigre", "leon", "elefante", "hipopotamo"]
for animal in animales:
    print(animal)
# Out:
# panda
# tigre
# leon
# elefante
# hipopotamo

# %%
nombre_de_usuario = input("ingrese el nombre del cliente")
producto = input("ingrese producto vendido")
cantidad = int(input("ingrese cantidad comprada"))
def comprar_el_producto(nombre, producto, cantidad):
    print(f"el nombre del cliente es {nombre}, su producto es {producto}, y lleva la cantidad de {cantidad}")

comprar_el_producto(nombre_de_usuario, producto, cantidad)
# Out:
# el nombre del cliente es vianca, su producto es pod, y lleva la cantidad de 10

# %%
numero1 =int(input("ingrese un numero"))
numero2 =int(input("ingrese un numero"))

def sumar(a,b):
    print(f"el resultado de la suma es {suma}")

suma = numero1+numero2
sumar(numero1,numero2)
# Out:
# el resultado de la suma es 7

# %%
numero_secreto = 9
intentos = 6

while intentos > 0:
    numero = int(input("Adivina el número: "))

    if numero == numero_secreto:
        print("¡Correcto! Adivinaste el número ")
        break
    else:
        intentos = intentos - 1

        if numero < numero_secreto:
            print("El número a adivinar es mayor")
        else:
            print("El número a adivinar es menor")

        print("Te quedan", intentos, "intentos")

if intentos == 0:
    print("Se acabaron los intentos ")

# %%
numero= 10
numero = input ("ingrese un numero")
while numero != 10:
    numero= input("numero incorrecto, ingresar numero")
    print ("correcto")

# %%
contador = 1 
while contador <=5:
    print(contador)
    contador = contador+1
# Out:
# 1
# 2
# 3
# 4
# 5
