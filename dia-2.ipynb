# %%
#condicionales
if True:
    print("hola")
elif False("hola2")

# %%
cont=0
palabras = input("Introducir ls palabra")
for caracter in palabras:
    
    
    if len(caracter) == "O" or caracter == "o":
        cont=cont+1
        print("letra o encontrada")

print (f"hay {cont} letras o en la frace", palabras)
# Out:
# letra o encontrada
# letra o encontrada
# letra o encontrada
# hay3 letras o en la frace solo yo

# %%
lista_de_marcas = ["Nike" , "dior", "Charlotte tilbury", "Reblon", "Swarovski"]
for marca in lista_de_marcas:
   
    if  len(marca)>=6:
        print(marca)
# Out:
# Charlotte tilbury
# Reblon
# Swarovski

# %%
for i in range(10):
    print(i*2)

# %%
lista_de_super = ["arroz", "leche", "pan", "manteca", "mayonesa"]
print (lista_de_super)
#agregar un elemento
lista_de_super.append("limon")
print (lista_de_super)
#modificar el segundo elemento
lista_de_super[2] = "cafe"
print(lista_de_super)
#eliminar el tercer elemento
lista_de_super.pop(2)
print(lista_de_super)
# Out:
# ['arroz', 'leche', 'pan', 'manteca', 'mayonesa']
# ['arroz', 'leche', 'pan', 'manteca', 'mayonesa', 'limon']
# ['arroz', 'leche', 'cafe', 'manteca', 'mayonesa', 'limon']
# ['arroz', 'leche', 'manteca', 'mayonesa', 'limon']

# %%
contraseña = ("oliveratom")
contraseña_ingresada = ''
# inicio del bucle
while True:
    contraseña_ingresada = input("ingresar contraseña")
    if contraseña_ingresada == contraseña:
        print("la contraseña es correcta")
        break
    else:
        print("el numero es incorrecto, intentelo de nuevo")
# Out:
# el numero es incorrecto, intentelo de nuevo
# el numero es incorrecto, intentelo de nuevo
# la contraseña es correcta

# %%
temperatura = float(input("Ingresa la temperatura"))

print(f"la temperatura ingresada es de {temperatura}")

if temperatura >= -10 and temperatura <= 13:
    print ("ro'y koko🥶")
elif temperatura >= 14 and temperatura <= 23:
    print ("Refresca'i❄️")
elif temperatura >= 24 and temperatura <= 28:
    print ("oikoite😄")
elif temperatura >= 29 and temperatura <= 45:
    print ("hakuro🌡️")
else:
    print ("Ñamano porandema")
# Out:
# la temperatura ingresada es de -11.0
# Ñamano porandema

# %%
edad_del_usuario = int(input ("Que edad tienes"))
#si menor de 18 años
if edad_del_usuario < 18:
    print("Acceso denegado - Solo zona kids")
elif edad_del_usuario < 21:
    print("acceso permitido - no puede comprar bebidas alcoholicas") 
else:
    print("Acceso total- Disfruta de la fiesta")
# Out:
# Acceso total- Disfruta de la fiesta
